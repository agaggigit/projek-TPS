# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from fitting_utils import uji_data, plot_histogram_fit, uji_dsitribusi, buat_kesimpulan

sns.set_theme(style="whitegrid")

# %%
# =============================================
# ========  Uncomment jika diperlukan  ========
# =============================================

# df_s1_totaltime = pd.read_csv(r"..\data\sesi1\TPS fulltank - S1 - Total Waktu.csv")
df_s1_itrarrival = pd.read_csv(r"..\data\sesi1\TPS fulltank - S1 - Inter Arrival.csv")

df_s2_servtime = pd.read_csv(r"..\data\sesi2\TPS fulltank - S2 - Waktu Pelayanan.csv")
# df_s2_que = pd.read_csv(r"..\data\sesi2\TPS fulltank - S2 - Antrian.csv")
# df_s2_quetime = pd.read_csv(r"..\data\sesi2\TPS fulltank - S2 - Waktu Mengantri.csv")
# df_s2_totaltime = pd.read_csv(r"..\data\sesi2\TPS fulltank - S2 - Waktu Total.csv")
df_s2_itrarrival = pd.read_csv(r"..\data\sesi2\TPS fulltank - S2 - InterArrival.csv")

df_s3_servtime = pd.read_csv(r"..\data\sesi3\TPS fulltank - S3 - Waktu Pelayanan.csv")
# df_s3_que = pd.read_csv(r"..\data\sesi3\TPS fulltank - S3 - Panjang Antrian.csv")
# df_s3_quetime = pd.read_csv(r"..\data\sesi3\TPS fulltank - S3 - Waktu Mengantri.csv")
# df_s3_totaltime = pd.read_csv(r"..\data\sesi3\TPS fulltank - S3 - Total Waktu.csv")
df_s3_itrarrival = pd.read_csv(r"..\data\sesi3\TPS fulltank - S3 - Interarrival.csv")

df_s4_servtime = pd.read_csv(r"..\data\sesi4\TPS fulltank - S4 - Waktu Pelayanan.csv")
# df_s4_que = pd.read_csv(r"..\data\sesi4\TPS fulltank - S4 - Panjang Antrian.csv")
# df_s4_quetime = pd.read_csv(r"..\data\sesi4\TPS fulltank - S4 - Waktu Mengantri.csv")
# df_s4_totaltime = pd.read_csv(r"..\data\sesi4\TPS fulltank - S4 - Waktu Total.csv")
df_s4_itrarrival = pd.read_csv(r"..\data\sesi4\TPS fulltank - S4 - Interarrival.csv")

# df_rekap = pd.read_csv(r"..\data\TPS fulltank - Rekap.csv")

# %%
datasets = {
    "Sesi 1": {"interarrival": df_s1_itrarrival},
    "Sesi 2": {"interarrival": df_s2_itrarrival, "service": df_s2_servtime},
    "Sesi 3": {"interarrival": df_s3_itrarrival, "service": df_s3_servtime},
    "Sesi 4": {"interarrival": df_s4_itrarrival, "service": df_s4_servtime},
}

# %%
df_summary = buat_kesimpulan(datasets)
df_summary
# Out:
# ========================================
#   Sesi 1
# ========================================
# Distribusi expon: p-value = 0.9902 (H0 Diterima)
# Distribusi norm: p-value = 0.6817 (H0 Diterima)
# Distribusi gamma: p-value = 0.9704 (H0 Diterima)
# ========================================
#   Sesi 2
# ========================================
# Distribusi expon: p-value = 0.2000 (H0 Diterima)
# Distribusi norm: p-value = 0.6146 (H0 Diterima)
# Distribusi gamma: p-value = 0.2881 (H0 Diterima)
# Distribusi expon: p-value = 0.0005 (H0 Ditolak)
# Distribusi norm: p-value = 0.1475 (H0 Diterima)
# Distribusi gamma: p-value = 0.2970 (H0 Diterima)
# ========================================
#   Sesi 3
# ========================================
# Distribusi expon: p-value = 0.6635 (H0 Diterima)
# Distribusi norm: p-value = 0.1338 (H0 Diterima)
# Distribusi gamma: p-value = 0.0254 (H0 Ditolak)
# Distribusi expon: p-value = 0.0000 (H0 Ditolak)
# Distribusi norm: p-value = 0.6459 (H0 Diterima)
# Distribusi gamma: p-value = 0.9212 (H0 Diterima)
# ========================================
#   Sesi 4
# ========================================
# Distribusi expon: p-value = 0.9508 (H0 Diterima)
# Distribusi norm: p-value = 0.0869 (H0 Diterima)
# Distribusi gamma: p-value = 0.9466 (H0 Diterima)
# Distribusi expon: p-value = 0.0000 (H0 Ditolak)
# Distribusi norm: p-value = 0.6599 (H0 Diterima)
# Distribusi gamma: p-value = 0.8864 (H0 Diterima)
#      Sesi  Interarrival Expon p-value Model Kedatangan Service Expon p-value  \
# 0  Sesi 1                      0.9902                M                     -
# 1  Sesi 2                      0.2000                M                0.0005
# 2  Sesi 3                      0.6635                M                   0.0
# 3  Sesi 4                      0.9508                M                   0.0
#
#   Model Pelayanan          Model Antrian
# 0               -  Belum bisa ditentukan
# 1               G                  M/G/1
# 2               G                  M/G/1
# 3               G                  M/G/1
